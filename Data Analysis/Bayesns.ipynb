# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import statistics

# %%
df = pd.read_csv('NewBankChurners.csv')
df.head(20)
# Out:
#     CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0   768805383  Existing Customer            45      M                3
# 1   818770008  Existing Customer            49      F                5
# 2   713982108  Existing Customer            51      M                3
# 3   769911858  Existing Customer            40      F                4
# 4   709106358  Existing Customer            40      M                3
# 5   713061558  Existing Customer            44      M                2
# 6   810347208  Existing Customer            51      M                4
# 7   818906208  Existing Customer            32      M                0
# 8   710930508  Existing Customer            37      M                3
# 9   719661558  Existing Customer            48      M                2
# 10  708790833  Existing Customer            42      M                5
# 11  710821833  Existing Customer            65      M                1
# ...

# %%
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
df.head(20)
# Out:
#     CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0   768805383  Existing Customer            45      M                3
# 1   818770008  Existing Customer            49      F                5
# 2   713982108  Existing Customer            51      M                3
# 3   769911858  Existing Customer            40      F                4
# 4   709106358  Existing Customer            40      M                3
# 5   713061558  Existing Customer            44      M                2
# 6   810347208  Existing Customer            51      M                4
# 7   818906208  Existing Customer            32      M                0
# 8   710930508  Existing Customer            37      M                3
# 9   719661558  Existing Customer            48      M                2
# 10  708790833  Existing Customer            42      M                5
# 11  710821833  Existing Customer            65      M                1
# ...

# %%
#Check for duplicate
print('---Check for duplicate---')
print(df[df.duplicated(keep=False)])
print('\n')

print('---Check for duplicate IDS---')
print(df.duplicated(subset=['CLIENTNUM']).unique())
print('\n')

#check for Unknown Values
print('---Check for Unknowns---')
print(df[df == 'Unknown'].count())
print('\n')

#Check for Zero Values
print('---Check for 0 Values---')
df[df == 0].count()
# Out:
# ---Check for duplicate---
# Empty DataFrame
# Columns: [CLIENTNUM, Attrition_Flag, Customer_Age, Gender, Dependent_count, Education_Level, Marital_Status, Income_Category, Card_Category, Months_on_book, Total_Relationship_Count, Months_Inactive_12_mon, Contacts_Count_12_mon, Credit_Limit, Total_Revolving_Bal, Avg_Open_To_Buy, Total_Amt_Chng_Q4_Q1, Total_Trans_Amt, Total_Trans_Ct, Total_Ct_Chng_Q4_Q1, Avg_Utilization_Ratio]
# Index: []
#
# [0 rows x 21 columns]
#
#
# ---Check for duplicate IDS---
# [False]
#
#
# ---Check for Unknowns---
# CLIENTNUM                      0
# Attrition_Flag                 0
# Customer_Age                   0
# Gender                         0
# Dependent_count                0
# Education_Level             1519
# Marital_Status               749
# Income_Category             1112
# Card_Category                  0
# Months_on_book                 0
# Total_Relationship_Count       0
# Months_Inactive_12_mon         0
# Contacts_Count_12_mon          0
# ...

# %%
df = df.drop(columns=['CLIENTNUM'])
df.columns
# Out:
# Index(['Attrition_Flag', 'Customer_Age', 'Gender', 'Dependent_count',
#        'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category',
#        'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Attrition_Flag', 'Customer_Age', 'Gender', 'Dependent_count',
#        'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category',
#        'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='Total_Relationship_Count',data=df,kde=True);

plt.figure(figsize=(10,5))
sns.histplot(x='Months_on_book',data=df,kde=True);

plt.figure(figsize=(10,5))
sns.histplot(x='Months_Inactive_12_mon',data=df,kde=True);

plt.figure(figsize=(10,5))
sns.histplot(x='Dependent_count',data=df,kde=True);

plt.figure(figsize=(10,5))
sns.histplot(x='Total_Revolving_Bal',data=df,kde=True);

plt.figure(figsize=(10,5))
sns.histplot(x='Avg_Open_To_Buy',data=df,kde=True);

plt.figure(figsize=(10,5))
sns.histplot(x='Total_Amt_Chng_Q4_Q1',data=df,kde=True);

plt.figure(figsize=(10,5))
sns.histplot(x='Total_Trans_Amt',data=df,kde=True);

plt.figure(figsize=(10,5))
sns.histplot(x='Total_Trans_Ct',data=df,kde=True);

plt.figure(figsize=(10,5))
sns.histplot(x='Total_Ct_Chng_Q4_Q1',data=df,kde=True);

plt.figure(figsize=(10,5))
sns.histplot(x='Avg_Utilization_Ratio',data=df,kde=True);

plt.figure(figsize=(10,5))
sns.histplot(x='Contacts_Count_12_mon',data=df,kde=True);

plt.figure(figsize=(10,5))
sns.histplot(x='Credit_Limit',data=df,kde=True);

# %% [markdown]
# # Credit Limit

# %%
df['Credit_Limit'].describe()
# Out:
# count    10127.000000
# mean      8631.953698
# std       9088.776650
# min       1438.300000
# 25%       2555.000000
# 50%       4549.000000
# 75%      11067.500000
# max      34516.000000
# Name: Credit_Limit, dtype: float64

# %%
credit_limit_min_value = df['Credit_Limit'].min()
credit_limit_max_value = df['Credit_Limit'].max()
print("Minimum Value for Credit Limit = " + str(credit_limit_min_value))
print("Maximum Value for Credit Limit = " + str(credit_limit_max_value))
# Out:
# Minimum Value for Credit Limit = 1438.3
# Maximum Value for Credit Limit = 34516.0

# %%
#df['Credit_Limit'].median()

# %%
credit_limit_bins = np.linspace(credit_limit_min_value, credit_limit_max_value, 4)
credit_limit_bins
# Out:
# array([ 1438.3, 12464.2, 23490.1, 34516. ])

# %%
labels = ['low', 'mid', 'high']

df['credit_limit_bins'] = pd.cut(df['Credit_Limit'], bins=credit_limit_bins, labels=labels, include_lowest=True)

# %%
plt.hist(df['credit_limit_bins'], bins=3)
# Out:
# (array([1231., 7892., 1004.]),
#  array([0.        , 0.66666667, 1.33333333, 2.        ]),
#  <BarContainer object of 3 artists>)

# %%
df.columns
# Out:
# Index(['Attrition_Flag', 'Customer_Age', 'Gender', 'Dependent_count',
#        'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category',
#        'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'credit_limit_bins'],
#       dtype='object')

# %%
df.head(20)
# Out:
#        Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0   Existing Customer            45      M                3     High School
# 1   Existing Customer            49      F                5        Graduate
# 2   Existing Customer            51      M                3        Graduate
# 3   Existing Customer            40      F                4     High School
# 4   Existing Customer            40      M                3      Uneducated
# 5   Existing Customer            44      M                2        Graduate
# 6   Existing Customer            51      M                4         Unknown
# 7   Existing Customer            32      M                0     High School
# 8   Existing Customer            37      M                3      Uneducated
# 9   Existing Customer            48      M                2        Graduate
# 10  Existing Customer            42      M                5      Uneducated
# ...

# %% [markdown]
# # Customer Age

# %%
min_value = df['Customer_Age'].min()
max_value = df['Customer_Age'].max()
print("Minimum Value for Credit Limit = " + str(min_value))
print("Maximum Value for Credit Limit = " + str(max_value))
# Out:
# Minimum Value for Credit Limit = 26
# Maximum Value for Credit Limit = 73

# %%
df['Customer_Age'].median()
# Out:
# 46.0

# %%
Customer_Age_bins = np.linspace(min_value, max_value, 4)
Customer_Age_bins
# Out:
# array([26.        , 41.66666667, 57.33333333, 73.        ])

# %%
Customer_Age_bins = np.round(Customer_Age_bins)

# %%
Customer_Age_bins
# Out:
# array([26., 42., 57., 73.])

# %%
labels = ['26 - 42', '43 - 57', '57 +']

df['Customer_Age_bins'] = pd.cut(df['Customer_Age'], bins=Customer_Age_bins, labels=labels, include_lowest=True)

# %%
plt.hist(df['Customer_Age_bins'], bins=3)
# Out:
# (array([6079., 3202.,  846.]),
#  array([0.        , 0.66666667, 1.33333333, 2.        ]),
#  <BarContainer object of 3 artists>)

# %%
df.head(20)
# Out:
#        Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0   Existing Customer            45      M                3     High School
# 1   Existing Customer            49      F                5        Graduate
# 2   Existing Customer            51      M                3        Graduate
# 3   Existing Customer            40      F                4     High School
# 4   Existing Customer            40      M                3      Uneducated
# 5   Existing Customer            44      M                2        Graduate
# 6   Existing Customer            51      M                4         Unknown
# 7   Existing Customer            32      M                0     High School
# 8   Existing Customer            37      M                3      Uneducated
# 9   Existing Customer            48      M                2        Graduate
# 10  Existing Customer            42      M                5      Uneducated
# ...

# %%
df[['Customer_Age_bins', 'Customer_Age']].head(50)
# Out:
#    Customer_Age_bins  Customer_Age
# 0            43 - 57            45
# 1            43 - 57            49
# 2            43 - 57            51
# 3            26 - 42            40
# 4            26 - 42            40
# 5            43 - 57            44
# 6            43 - 57            51
# 7            26 - 42            32
# 8            26 - 42            37
# 9            43 - 57            48
# 10           26 - 42            42
# 11              57 +            65
# 12           43 - 57            56
# 13           26 - 42            35
# 14           43 - 57            57
# 15           43 - 57            44
# 16           43 - 57            48
# 17           26 - 42            41
# 18              57 +            61
# 19           43 - 57            45
# 20           43 - 57            47
# 21              57 +            62
# 22           26 - 42            41
# 23           43 - 57            47
# 24           43 - 57            54
# 25           26 - 42            41
# ...

# %%
count = (df['Customer_Age'] == 41).sum()
count
# Out:
# 379

# %%
df.loc[df['Customer_Age'] == 42]
# Out:
#           Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10     Existing Customer            42      M                5
# 37     Existing Customer            42      F                4
# 59     Existing Customer            42      M                2
# 73     Existing Customer            42      M                5
# 111    Existing Customer            42      M                3
# ...                  ...           ...    ...              ...
# 10027  Existing Customer            42      F                1
# 10029  Existing Customer            42      M                3
# 10080  Existing Customer            42      F                4
# 10083  Existing Customer            42      F                4
# 10101  Existing Customer            42      M                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10         Uneducated        Unknown         $120K +          Blue
# 37        High School        Married  Less than $40K          Gold
# ...

# %% [markdown]
# # Total Revolving Balance

# %%
min_value = df['Total_Revolving_Bal'].min()
max_value = df['Total_Revolving_Bal'].max()
print("Minimum Value for Credit Limit = " + str(min_value))
print("Maximum Value for Credit Limit = " + str(max_value))

df['Total_Revolving_Bal'].median()

Total_Revolving_Bal_bins = np.linspace(min_value, max_value, 4)
Total_Revolving_Bal_bins
# Out:
# Minimum Value for Credit Limit = 0
# Maximum Value for Credit Limit = 2517
# array([   0.,  839., 1678., 2517.])

# %%
labels = ['low', 'mid', 'high']

df['Total_Revolving_Bal_bins'] = pd.cut(df['Total_Revolving_Bal'], bins=Total_Revolving_Bal_bins, labels=labels, include_lowest=True)

# %%
plt.hist(df['Total_Revolving_Bal_bins'], bins=3)
# Out:
# (array([3332., 3782., 3013.]),
#  array([0.        , 0.66666667, 1.33333333, 2.        ]),
#  <BarContainer object of 3 artists>)

# %%
df.loc[df['Total_Revolving_Bal'] == 1679]
# Out:
#          Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 203   Existing Customer            47      M                4        Graduate
# 1877  Existing Customer            35      F                4     High School
# 3230  Existing Customer            46      F                0        Graduate
# 9470  Existing Customer            48      F                4         Unknown
#
#      Marital_Status Income_Category Card_Category  Months_on_book  \
# 203         Married     $60K - $80K        Silver              33
# 1877         Single         Unknown          Blue              24
# 3230       Divorced         Unknown          Blue              36
# 9470         Single     $40K - $60K          Blue              36
#
#       Total_Relationship_Count  ...  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 203                          3  ...                 1679          32837.0
# 1877                         5  ...                 1679          15236.0
# ...

# %%
df[['Total_Revolving_Bal_bins', 'Total_Revolving_Bal']].head(50)
# Out:
#    Total_Revolving_Bal_bins  Total_Revolving_Bal
# 0                       low                  777
# 1                       mid                  864
# 2                       low                    0
# 3                      high                 2517
# 4                       low                    0
# 5                       mid                 1247
# 6                      high                 2264
# 7                       mid                 1396
# 8                      high                 2517
# 9                       mid                 1677
# 10                      mid                 1467
# 11                      mid                 1587
# 12                      low                    0
# 13                      mid                 1666
# 14                      low                  680
# 15                      mid                  972
# 16                     high                 2362
# 17                      mid                 1291
# ...

# %%
df.columns
# Out:
# Index(['Attrition_Flag', 'Customer_Age', 'Gender', 'Dependent_count',
#        'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category',
#        'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'credit_limit_bins', 'Customer_Age_bins', 'Total_Revolving_Bal_bins'],
#       dtype='object')

# %% [markdown]
# # Dependent Count

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='Dependent_count',data=df,kde=True);

# %%
min_value = df['Dependent_count'].min()
max_value = df['Dependent_count'].max()
print("Minimum Value for Credit Limit = " + str(min_value))
print("Maximum Value for Credit Limit = " + str(max_value))

print(df['Dependent_count'].median())

Dependent_count_bins = np.linspace(min_value, max_value, 3)
print(Dependent_count_bins)
# Out:
# Minimum Value for Credit Limit = 0
# Maximum Value for Credit Limit = 5
# 2.0
# [0.  2.5 5. ]

# %%
Dependent_count_bins = np.round(Dependent_count_bins)

# %%
Dependent_count_bins
# Out:
# array([0., 2., 5.])

# %%
labels = ['0 - 2', '3 - 5']

df['Dependent_count_bins'] = pd.cut(df['Dependent_count'], bins=Dependent_count_bins, labels=labels, include_lowest=True)

# %%
plt.hist(df['Dependent_count_bins'], bins=2)
# Out:
# (array([4730., 5397.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)

# %%
df[['Dependent_count_bins', 'Dependent_count']].head(50)
# Out:
#    Dependent_count_bins  Dependent_count
# 0                 3 - 5                3
# 1                 3 - 5                5
# 2                 3 - 5                3
# 3                 3 - 5                4
# 4                 3 - 5                3
# 5                 0 - 2                2
# 6                 3 - 5                4
# 7                 0 - 2                0
# 8                 3 - 5                3
# 9                 0 - 2                2
# 10                3 - 5                5
# 11                0 - 2                1
# 12                0 - 2                1
# 13                3 - 5                3
# 14                0 - 2                2
# 15                3 - 5                4
# 16                3 - 5                4
# 17                3 - 5                3
# 18                0 - 2                1
# 19                0 - 2                2
# 20                0 - 2                1
# 21                0 - 2                0
# ...

# %%
df.columns
# Out:
# Index(['Attrition_Flag', 'Customer_Age', 'Gender', 'Dependent_count',
#        'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category',
#        'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'credit_limit_bins', 'Customer_Age_bins', 'Total_Revolving_Bal_bins',
#        'Dependent_count_bins'],
#       dtype='object')

# %% [markdown]
# # Months_on_Book

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='Months_on_book',data=df,kde=True);

# %%
min_value = df['Months_on_book'].min()
max_value = df['Months_on_book'].max()
print("Minimum Value for Credit Limit = " + str(min_value))
print("Maximum Value for Credit Limit = " + str(max_value))

print(df['Months_on_book'].median())

Months_on_book_bins = np.linspace(min_value, max_value, 4)
print(Months_on_book_bins)
Months_on_book_bins = np.round(Months_on_book_bins)
Months_on_book_bins
# Out:
# Minimum Value for Credit Limit = 13
# Maximum Value for Credit Limit = 56
# 36.0
# [13.         27.33333333 41.66666667 56.        ]
# array([13., 27., 42., 56.])

# %%
labels = ['13 - 27', '28 - 42', '43 - 56']

df['Months_on_book_bins'] = pd.cut(df['Months_on_book'], bins=Months_on_book_bins, labels=labels, include_lowest=True)


plt.hist(df['Months_on_book_bins'], bins=3)

df[['Months_on_book_bins', 'Months_on_book']].head(50)

df.loc[df['Months_on_book'] == 43]
# Out:
#          Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 42    Existing Customer            50      F                1         College
# 72    Existing Customer            54      M                1        Graduate
# 100   Existing Customer            49      F                3         College
# 133   Existing Customer            52      M                1        Graduate
# 160   Existing Customer            56      M                0     High School
# ...                 ...           ...    ...              ...             ...
# 9854  Attrited Customer            51      F                4   Post-Graduate
# 9855  Existing Customer            53      F                4     High School
# 9909  Existing Customer            53      M                3         Unknown
# 9945  Existing Customer            50      M                4     High School
# 9956  Existing Customer            48      F                5         Unknown
#
# ...

# %% [markdown]
# # Months_Inactive_12_mon

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='Months_Inactive_12_mon',data=df,kde=True);

# %%
min_value = df['Months_Inactive_12_mon'].min()
max_value = df['Months_Inactive_12_mon'].max()
print("Minimum Value for Credit Limit = " + str(min_value))
print("Maximum Value for Credit Limit = " + str(max_value))

print(df['Months_Inactive_12_mon'].median())

Months_Inactive_12_mon_bins = np.linspace(min_value, max_value, 3)
print(Months_Inactive_12_mon_bins)
Months_Inactive_12_mon_bins = np.round(Months_Inactive_12_mon_bins)
Months_Inactive_12_mon_bins
# Out:
# Minimum Value for Credit Limit = 0
# Maximum Value for Credit Limit = 6
# 2.0
# [0. 3. 6.]
# array([0., 3., 6.])

# %%
labels = ['1 - 3', '4 - 6']

df['Months_Inactive_12_mon_bins'] = pd.cut(df['Months_Inactive_12_mon'], bins=Months_Inactive_12_mon_bins, labels=labels, include_lowest=True)


plt.hist(df['Months_Inactive_12_mon_bins'], bins=2)

df[['Months_Inactive_12_mon_bins', 'Months_Inactive_12_mon']].head(50)

#df.loc[df['Months_Inactive_12_mon'] == 43]
# Out:
#    Months_Inactive_12_mon_bins  Months_Inactive_12_mon
# 0                        1 - 3                       1
# 1                        1 - 3                       1
# 2                        1 - 3                       1
# 3                        4 - 6                       4
# 4                        1 - 3                       1
# 5                        1 - 3                       1
# 6                        1 - 3                       1
# 7                        1 - 3                       2
# 8                        1 - 3                       2
# 9                        1 - 3                       3
# 10                       1 - 3                       3
# 11                       1 - 3                       2
# 12                       4 - 6                       6
# 13                       1 - 3                       1
# 14                       1 - 3                       2
# 15                       1 - 3                       1
# ...

# %% [markdown]
# # Total_Relationship_Count

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='Total_Relationship_Count',data=df,kde=True);

# %%
min_value = df['Total_Relationship_Count'].min()
max_value = df['Total_Relationship_Count'].max()
print("Minimum Value for Credit Limit = " + str(min_value))
print("Maximum Value for Credit Limit = " + str(max_value))

print(df['Total_Relationship_Count'].median())

Total_Relationship_Count_bins = np.linspace(min_value, max_value, 4)
print(Total_Relationship_Count_bins)
Total_Relationship_Count_bins = np.round(Total_Relationship_Count_bins)
Total_Relationship_Count_bins
# Out:
# Minimum Value for Credit Limit = 1
# Maximum Value for Credit Limit = 6
# 4.0
# [1.         2.66666667 4.33333333 6.        ]
# array([1., 3., 4., 6.])

# %%
labels = ['1 - 3', '4 ', '5 - 6']

df['Total_Relationship_Count_bins'] = pd.cut(df['Total_Relationship_Count'], bins=Total_Relationship_Count_bins, labels=labels, include_lowest=True)


plt.hist(df['Total_Relationship_Count_bins'], bins=3)

df[['Total_Relationship_Count_bins', 'Total_Relationship_Count']].head(50)

#df.loc[df['Months_Inactive_12_mon'] == 43]
# Out:
#    Total_Relationship_Count_bins  Total_Relationship_Count
# 0                          5 - 6                         5
# 1                          5 - 6                         6
# 2                             4                          4
# 3                          1 - 3                         3
# 4                          5 - 6                         5
# 5                          1 - 3                         3
# 6                          5 - 6                         6
# 7                          1 - 3                         2
# 8                          5 - 6                         5
# 9                          5 - 6                         6
# 10                         5 - 6                         5
# 11                         5 - 6                         6
# 12                         1 - 3                         3
# 13                         5 - 6                         5
# 14                         5 - 6                         5
# ...

# %% [markdown]
# # Contacts_Count_12_mon

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='Contacts_Count_12_mon',data=df,kde=True);

# %%
min_value = df['Contacts_Count_12_mon'].min()
max_value = df['Contacts_Count_12_mon'].max()
print("Minimum Value for Credit Limit = " + str(min_value))
print("Maximum Value for Credit Limit = " + str(max_value))

print(df['Contacts_Count_12_mon'].median())

Contacts_Count_12_mon_bins = np.linspace(min_value, max_value, 3)
print(Contacts_Count_12_mon_bins)
Contacts_Count_12_mon_bins = np.round(Contacts_Count_12_mon_bins)
Contacts_Count_12_mon_bins
# Out:
# Minimum Value for Credit Limit = 0
# Maximum Value for Credit Limit = 6
# 2.0
# [0. 3. 6.]
# array([0., 3., 6.])

# %%
labels = ['1 - 3', '4 - 6']

df['Contacts_Count_12_mon_bins'] = pd.cut(df['Contacts_Count_12_mon'], bins=Contacts_Count_12_mon_bins, labels=labels, include_lowest=True)


plt.hist(df['Contacts_Count_12_mon_bins'], bins=2)

df[['Contacts_Count_12_mon_bins', 'Contacts_Count_12_mon']].tail(50)

#df.loc[df['Contacts_Count_12_mon'] == 4]
# Out:
#       Contacts_Count_12_mon_bins  Contacts_Count_12_mon
# 10077                      1 - 3                      0
# 10078                      1 - 3                      2
# 10079                      4 - 6                      4
# 10080                      1 - 3                      3
# 10081                      1 - 3                      2
# 10082                      1 - 3                      2
# 10083                      1 - 3                      2
# 10084                      1 - 3                      2
# 10085                      4 - 6                      4
# 10086                      1 - 3                      3
# 10087                      1 - 3                      2
# 10088                      1 - 3                      2
# 10089                      1 - 3                      3
# 10090                      1 - 3                      3
# 10091                      4 - 6                      4
# 10092                      1 - 3                      3
# ...

# %% [markdown]
# # Total_Trans_Amt

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='Total_Trans_Amt',data=df,kde=True);

# %%
min_value = df['Total_Trans_Amt'].min()
max_value = df['Total_Trans_Amt'].max()
print("Minimum Value for Credit Limit = " + str(min_value))
print("Maximum Value for Credit Limit = " + str(max_value))

print(df['Contacts_Count_12_mon'].median())

Total_Trans_Amt_bins = np.linspace(min_value, max_value, 4)
print(Total_Trans_Amt_bins)
Total_Trans_Amt_bins = np.round(Total_Trans_Amt_bins)
Total_Trans_Amt_bins
# Out:
# Minimum Value for Credit Limit = 510
# Maximum Value for Credit Limit = 18484
# 2.0
# [  510.          6501.33333333 12492.66666667 18484.        ]
# array([  510.,  6501., 12493., 18484.])

# %%
labels = ['less than 6500', 'less than 12492', 'more than 12492']

df['Total_Trans_Amt_bins'] = pd.cut(df['Total_Trans_Amt'], bins=Total_Trans_Amt_bins, labels=labels, include_lowest=True)


plt.hist(df['Total_Trans_Amt_bins'], bins=3)

df[['Total_Trans_Amt_bins', 'Total_Trans_Amt']].tail(50)

#df.loc[df['Total_Trans_Amt'] == 6500]
# Out:
#       Total_Trans_Amt_bins  Total_Trans_Amt
# 10077      more than 12492            15123
# 10078      more than 12492            15925
# 10079      more than 12492            14875
# 10080      more than 12492            16622
# 10081      more than 12492            16202
# 10082      more than 12492            16715
# 10083      more than 12492            15905
# 10084      more than 12492            14908
# 10085      more than 12492            15277
# 10086      more than 12492            16177
# 10087      more than 12492            15380
# 10088      more than 12492            13940
# 10089      less than 12492             7636
# 10090      more than 12492            15681
# 10091      more than 12492            16344
# 10092      less than 12492             9038
# 10093      more than 12492            15349
# 10094      more than 12492            14873
# 10095      more than 12492            15490
# 10096      more than 12492            16518
# ...

# %% [markdown]
# # Avg_Open_To_Buy

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='Avg_Open_To_Buy',data=df,kde=True);

# %%
min_value = df['Avg_Open_To_Buy'].min()
max_value = df['Avg_Open_To_Buy'].max()
print("Minimum Value for Credit Limit = " + str(min_value))
print("Maximum Value for Credit Limit = " + str(max_value))

print(df['Avg_Open_To_Buy'].median())

Avg_Open_To_Buy_bins = np.linspace(min_value, max_value, 4)
print(Avg_Open_To_Buy_bins)
Avg_Open_To_Buy_bins = np.round(Avg_Open_To_Buy_bins)
Avg_Open_To_Buy_bins
# Out:
# Minimum Value for Credit Limit = 3.0
# Maximum Value for Credit Limit = 34516.0
# 3474.0
# [3.00000000e+00 1.15073333e+04 2.30116667e+04 3.45160000e+04]
# array([3.0000e+00, 1.1507e+04, 2.3012e+04, 3.4516e+04])

# %%
#labels = ['3 - 11507', '11508 - 23012', 'more than 23012']
labels = ['low', 'mid', 'high']

df['Avg_Open_To_Buy_bins'] = pd.cut(df['Avg_Open_To_Buy'], bins=Avg_Open_To_Buy_bins, labels=labels, include_lowest=True)


plt.hist(df['Avg_Open_To_Buy_bins'], bins=3)

df[['Avg_Open_To_Buy_bins', 'Avg_Open_To_Buy']].tail(50)

df.loc[df['Avg_Open_To_Buy'] == 11508]
# Out:
#          Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 9014  Attrited Customer            43      F                5         College
#
#      Marital_Status Income_Category Card_Category  Months_on_book  \
# 9014         Single     $40K - $60K          Blue              32
#
#       Total_Relationship_Count  ...  credit_limit_bins  Customer_Age_bins  \
# 9014                         2  ...                low            43 - 57
#
#       Total_Revolving_Bal_bins  Dependent_count_bins  Months_on_book_bins  \
# 9014                       low                 3 - 5              28 - 42
#
#       Months_Inactive_12_mon_bins  Total_Relationship_Count_bins  \
# 9014                        1 - 3                          1 - 3
#
#       Contacts_Count_12_mon_bins  Total_Trans_Amt_bins  Avg_Open_To_Buy_bins
# 9014                       1 - 3        less than 6500                   mid
#
# [1 rows x 30 columns]

# %% [markdown]
# # Total_Amt_Chng_Q4_Q1

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='Total_Amt_Chng_Q4_Q1',data=df,kde=True);

# %%
min_value = df['Total_Amt_Chng_Q4_Q1'].min()
max_value = df['Total_Amt_Chng_Q4_Q1'].max()
print("Minimum Value for Credit Limit = " + str(min_value))
print("Maximum Value for Credit Limit = " + str(max_value))

print(df['Total_Amt_Chng_Q4_Q1'].median())

Total_Amt_Chng_Q4_Q1_bins = np.linspace(min_value, max_value, 3)
print(Total_Amt_Chng_Q4_Q1_bins)
Total_Amt_Chng_Q4_Q1_bins = np.round(Total_Amt_Chng_Q4_Q1_bins)
Total_Amt_Chng_Q4_Q1_bins
# Out:
# Minimum Value for Credit Limit = 0.0
# Maximum Value for Credit Limit = 3.397
# 0.736
# [0.     1.6985 3.397 ]
# array([0., 2., 3.])

# %%
#labels = ['3 - 11507', '11508 - 23012', 'more than 23012']
labels = ['low -mid', 'high']

df['Total_Amt_Chng_Q4_Q1_bins'] = pd.cut(df['Total_Amt_Chng_Q4_Q1'], bins=Total_Amt_Chng_Q4_Q1_bins, labels=labels, include_lowest=True)



df[['Total_Amt_Chng_Q4_Q1_bins', 'Total_Amt_Chng_Q4_Q1']].head(50)

#df.loc[df['Total_Amt_Chng_Q4_Q1'] == 11508]
# Out:
#    Total_Amt_Chng_Q4_Q1_bins  Total_Amt_Chng_Q4_Q1
# 0                   low -mid                 1.335
# 1                   low -mid                 1.541
# 2                       high                 2.594
# 3                   low -mid                 1.405
# 4                       high                 2.175
# 5                   low -mid                 1.376
# 6                   low -mid                 1.975
# 7                       high                 2.204
# 8                        NaN                 3.355
# 9                   low -mid                 1.524
# 10                  low -mid                 0.831
# 11                  low -mid                 1.433
# 12                       NaN                 3.397
# 13                  low -mid                 1.163
# 14                  low -mid                 1.190
# 15                  low -mid                 1.707
# 16                  low -mid                 1.708
# ...

# %%
#plt.hist(df['Total_Amt_Chng_Q4_Q1_bins'], bins=2)

# %% [markdown]
# # Total_Ct_Chng_Q4_Q1

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='Total_Ct_Chng_Q4_Q1',data=df,kde=True);

# %%
min_value = df['Total_Ct_Chng_Q4_Q1'].min()
max_value = df['Total_Ct_Chng_Q4_Q1'].max()
print("Minimum Value for Credit Limit = " + str(min_value))
print("Maximum Value for Credit Limit = " + str(max_value))

print(df['Total_Ct_Chng_Q4_Q1'].median())

Total_Ct_Chng_Q4_Q1_bins = np.linspace(min_value, max_value, 3)
print(Total_Ct_Chng_Q4_Q1_bins)
Total_Ct_Chng_Q4_Q1_bins = np.round(Total_Ct_Chng_Q4_Q1_bins)
Total_Ct_Chng_Q4_Q1_bins
# Out:
# Minimum Value for Credit Limit = 0.0
# Maximum Value for Credit Limit = 3.714
# 0.702
# [0.    1.857 3.714]
# array([0., 2., 4.])

# %%
#labels = ['3 - 11507', '11508 - 23012', 'more than 23012']
labels = ['low -mid', 'high']

df['Total_Ct_Chng_Q4_Q1_bins'] = pd.cut(df['Total_Ct_Chng_Q4_Q1'], bins=Total_Ct_Chng_Q4_Q1_bins, labels=labels, include_lowest=True)



df[['Total_Ct_Chng_Q4_Q1_bins', 'Total_Ct_Chng_Q4_Q1']].head(50)

#df.loc[df['Total_Amt_Chng_Q4_Q1'] == 11508]
# Out:
#    Total_Ct_Chng_Q4_Q1_bins  Total_Ct_Chng_Q4_Q1
# 0                  low -mid                1.625
# 1                      high                3.714
# 2                      high                2.333
# 3                      high                2.333
# 4                      high                2.500
# 5                  low -mid                0.846
# 6                  low -mid                0.722
# 7                  low -mid                0.714
# 8                  low -mid                1.182
# 9                  low -mid                0.882
# 10                 low -mid                0.680
# 11                 low -mid                1.364
# 12                     high                3.250
# 13                 low -mid                2.000
# 14                 low -mid                0.611
# 15                 low -mid                1.700
# 16                 low -mid                0.929
# 17                 low -mid                1.625
# ...

# %%
plt.hist(df['Total_Ct_Chng_Q4_Q1_bins'], bins=2)
# Out:
# (array([10101.,    26.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)

# %% [markdown]
# # Total_Trans_Ct

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='Total_Trans_Ct',data=df,kde=True);

# %%
min_value = df['Total_Trans_Ct'].min()
max_value = df['Total_Trans_Ct'].max()
print("Minimum Value for Credit Limit = " + str(min_value))
print("Maximum Value for Credit Limit = " + str(max_value))

print(df['Total_Trans_Ct'].median())

Total_Trans_Ct_bins = np.linspace(min_value, max_value, 4)
print(Total_Trans_Ct_bins)
Total_Trans_Ct_bins = np.round(Total_Trans_Ct_bins)
Total_Trans_Ct_bins
# Out:
# Minimum Value for Credit Limit = 10
# Maximum Value for Credit Limit = 139
# 67.0
# [ 10.  53.  96. 139.]
# array([ 10.,  53.,  96., 139.])

# %%
#labels = ['3 - 11507', '11508 - 23012', 'more than 23012']
labels = ['10 - 53', '54 - 96', '97 - 139']

df['Total_Trans_Ct_bins'] = pd.cut(df['Total_Trans_Ct'], bins=Total_Trans_Ct_bins, labels=labels, include_lowest=True)



df[['Total_Trans_Ct_bins', 'Total_Trans_Ct']].head(50)

#df.loc[df['Total_Trans_Ct'] == 140]
# Out:
#    Total_Trans_Ct_bins  Total_Trans_Ct
# 0              10 - 53              42
# 1              10 - 53              33
# 2              10 - 53              20
# 3              10 - 53              20
# 4              10 - 53              28
# 5              10 - 53              24
# 6              10 - 53              31
# 7              10 - 53              36
# 8              10 - 53              24
# 9              10 - 53              32
# 10             10 - 53              42
# 11             10 - 53              26
# 12             10 - 53              17
# 13             10 - 53              33
# 14             10 - 53              29
# 15             10 - 53              27
# 16             10 - 53              27
# 17             10 - 53              21
# 18             10 - 53              30
# 19             10 - 53              21
# 20             10 - 53              27
# 21             10 - 53              16
# 22             10 - 53              18
# ...

# %%
plt.hist(df['Total_Trans_Ct_bins'], bins=3)
# Out:
# (array([3369., 5960.,  798.]),
#  array([0.        , 0.66666667, 1.33333333, 2.        ]),
#  <BarContainer object of 3 artists>)

# %% [markdown]
# # Avg_Utilization_Ratio

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='Avg_Utilization_Ratio',data=df,kde=True);

# %%
min_value = df['Avg_Utilization_Ratio'].min()
max_value = df['Avg_Utilization_Ratio'].max()
print("Minimum Value for Credit Limit = " + str(min_value))
print("Maximum Value for Credit Limit = " + str(max_value))

print(df['Avg_Utilization_Ratio'].median())

Avg_Utilization_Ratio_bins = np.linspace(min_value, max_value, 4)
print(Avg_Utilization_Ratio_bins)
#Avg_Utilization_Ratio_bins = np.round(Avg_Utilization_Ratio_bins)
Avg_Utilization_Ratio_bins
# Out:
# Minimum Value for Credit Limit = 0.0
# Maximum Value for Credit Limit = 0.999
# 0.176
# [0.    0.333 0.666 0.999]
# array([0.   , 0.333, 0.666, 0.999])

# %%
#labels = ['3 - 11507', '11508 - 23012', 'more than 23012']
labels = ['0 - 0.3', '0.3 - 0.6', '0.6 - 1']

df['Avg_Utilization_Ratio_bins'] = pd.cut(df['Avg_Utilization_Ratio'], bins=Avg_Utilization_Ratio_bins, labels=labels, include_lowest=True)



df[['Avg_Utilization_Ratio_bins', 'Avg_Utilization_Ratio']].head(50)

df.loc[df['Avg_Utilization_Ratio'] == 0.7]
# Out:
#          Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 1631  Existing Customer            54      M                3   Post-Graduate
# 1724  Existing Customer            64      M                1         Unknown
# 2665  Existing Customer            36      M                2        Graduate
# 7923  Existing Customer            53      F                3         Unknown
#
#      Marital_Status Income_Category Card_Category  Months_on_book  \
# 1631        Married         $120K +          Blue              42
# 1724        Married  Less than $40K          Blue              55
# 2665         Single    $80K - $120K          Blue              17
# 7923         Single  Less than $40K          Blue              42
#
#       Total_Relationship_Count  ...  Months_on_book_bins  \
# 1631                         6  ...              28 - 42
# 1724                         4  ...              43 - 56
# 2665                         4  ...              13 - 27
# ...

# %%
plt.hist(df['Avg_Utilization_Ratio_bins'], bins=3)
# Out:
# (array([6491., 1303., 2333.]),
#  array([0.        , 0.66666667, 1.33333333, 2.        ]),
#  <BarContainer object of 3 artists>)

# %%
df.columns
# Out:
# Index(['Attrition_Flag', 'Customer_Age', 'Gender', 'Dependent_count',
#        'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category',
#        'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'credit_limit_bins', 'Customer_Age_bins', 'Total_Revolving_Bal_bins',
#        'Dependent_count_bins', 'Months_on_book_bins',
#        'Months_Inactive_12_mon_bins', 'Total_Relationship_Count_bins',
#        'Contacts_Count_12_mon_bins', 'Total_Trans_Amt_bins',
#        'Avg_Open_To_Buy_bins', 'Total_Amt_Chng_Q4_Q1_bins',
#        'Total_Ct_Chng_Q4_Q1_bins', 'Total_Trans_Ct_bins',
#        'Avg_Utilization_Ratio_bins'],
#       dtype='object')

# %%
# Dropping the Naive_Bayes_Classifier columns (There are 2 in the dataset)

df_new = df.drop(columns=['Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon', 'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal', 'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt', 'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio','Customer_Age', 'Dependent_count'])
df_new.columns
# Out:
# Index(['Attrition_Flag', 'Gender', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'credit_limit_bins',
#        'Customer_Age_bins', 'Total_Revolving_Bal_bins', 'Dependent_count_bins',
#        'Months_on_book_bins', 'Months_Inactive_12_mon_bins',
#        'Total_Relationship_Count_bins', 'Contacts_Count_12_mon_bins',
#        'Total_Trans_Amt_bins', 'Avg_Open_To_Buy_bins',
#        'Total_Amt_Chng_Q4_Q1_bins', 'Total_Ct_Chng_Q4_Q1_bins',
#        'Total_Trans_Ct_bins', 'Avg_Utilization_Ratio_bins'],
#       dtype='object')

# %%
df_new.head(50)
# Out:
#        Attrition_Flag Gender Education_Level Marital_Status Income_Category  \
# 0   Existing Customer      M     High School        Married     $60K - $80K
# 1   Existing Customer      F        Graduate         Single  Less than $40K
# 2   Existing Customer      M        Graduate        Married    $80K - $120K
# 3   Existing Customer      F     High School        Unknown  Less than $40K
# 4   Existing Customer      M      Uneducated        Married     $60K - $80K
# 5   Existing Customer      M        Graduate        Married     $40K - $60K
# 6   Existing Customer      M         Unknown        Married         $120K +
# 7   Existing Customer      M     High School        Unknown     $60K - $80K
# 8   Existing Customer      M      Uneducated         Single     $60K - $80K
# 9   Existing Customer      M        Graduate         Single    $80K - $120K
# 10  Existing Customer      M      Uneducated        Unknown         $120K +
# ...

# %%
df_new.columns
# Out:
# Index(['Attrition_Flag', 'Gender', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'credit_limit_bins',
#        'Customer_Age_bins', 'Total_Revolving_Bal_bins', 'Dependent_count_bins',
#        'Months_on_book_bins', 'Months_Inactive_12_mon_bins',
#        'Total_Relationship_Count_bins', 'Contacts_Count_12_mon_bins',
#        'Total_Trans_Amt_bins', 'Avg_Open_To_Buy_bins',
#        'Total_Amt_Chng_Q4_Q1_bins', 'Total_Ct_Chng_Q4_Q1_bins',
#        'Total_Trans_Ct_bins', 'Avg_Utilization_Ratio_bins'],
#       dtype='object')

# %%
df_new.to_csv('Bayesys.csv')

# %%
df_new.columns
# Out:
# Index(['Attrition_Flag', 'Gender', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'credit_limit_bins',
#        'Customer_Age_bins', 'Total_Revolving_Bal_bins', 'Dependent_count_bins',
#        'Months_on_book_bins', 'Months_Inactive_12_mon_bins',
#        'Total_Relationship_Count_bins', 'Contacts_Count_12_mon_bins',
#        'Total_Trans_Amt_bins', 'Avg_Open_To_Buy_bins',
#        'Total_Amt_Chng_Q4_Q1_bins', 'Total_Ct_Chng_Q4_Q1_bins',
#        'Total_Trans_Ct_bins', 'Avg_Utilization_Ratio_bins'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Income_Category',data=df_new,palette='Set1',hue='Gender');

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Card_Category',data=df,palette='Set1',hue='Gender');

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Income_Category',data=df,palette='Set1',hue='Card_Category');

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Marital_Status',data=df_new,palette='Set1',hue='Gender');

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Marital_Status',data=df_new,palette='Set1',hue='Card_Category');

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Gender',data=df_new,palette='Set1',hue='Total_Trans_Ct_bins');

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Gender',data=df_new,palette='Set1',hue='Avg_Utilization_Ratio_bins');

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Customer_Age_bins',data=df_new,palette='Set1',hue='Income_Category');

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Customer_Age_bins',data=df_new,palette='Set1',hue='Dependent_count_bins');

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Customer_Age_bins',data=df_new,palette='Set1',hue='Marital_Status');

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Customer_Age_bins',data=df_new,palette='Set1',hue='Months_on_book_bins');

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Marital_Status',data=df_new,palette='Set1',hue='Education_Level');

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Income_Category',data=df_new,palette='Set1',hue='Education_Level');

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Income_Category',data=df_new,palette='Set1',hue='credit_limit_bins');
